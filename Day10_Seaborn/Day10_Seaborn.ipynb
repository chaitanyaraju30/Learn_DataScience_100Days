# %% [markdown]
# Distribution plots in seaborn are distplot,joinplot,pairplot

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# If the values are floats or integers , then only we can find the corelation else we can't find , becuase categorical values are object type.Always corelation exists between -1 to +1.

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Joinplot allows to study the relationship between 2 numeric variables.The central chart display their correlation.It is usually
# a scatterplot,a hexbin plot,a 2D histogram or a 2D density plot

# %%
sns.jointplot(x = 'tip',y='total_bill',data=df,kind='hex')

# %%
sns.jointplot(x = 'tip',y='total_bill',data=df,kind='reg')

# %% [markdown]
# Pair Plot is also know as scatterplot in which one variable in the same data row is matched with another variable's value
# like this: Pairs plots are just elaborations on this, showing all variables paired with all the other variables.Pair plots are ued when we have more than one independent variables.

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='smoker')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %% [markdown]
# Dist plot helps us to check the distribution of the column feature.

# %%
sns.distplot(df['tip'])
# Out:
# C:\Users\ratnachaitanyaraju.b\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df['tip'],kde=False,bins=10)
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# Categorical Plots are like boxplot,violinplot,countplot,bar plot

# %%
sns.countplot('sex',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(y = 'sex',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %%
sns.barplot(x='sex',y='tip',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x='sex',y='total_bill',data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot('sex','tip',data=df)
# Out:
# C:\Users\ratnachaitanyaraju.b\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x = 'day',y='tip',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(data=df,orient='v')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='total_bill',y='day',hue='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x='total_bill',y='day',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
iris = sns.load_dataset('iris')

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr())
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='resid')

# %%
sns.pairplot(iris,diag_kind='kde')

# %%
iris['sepal_length'].value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 6.2     4
# 5.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 7.2     3
# 5.9     3
# 4.4     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.1     1
# 7.4     1
# 7.6     1
# 7.9     1
# 4.5     1
# 7.0     1
# 5.3     1
# 7.3     1
# 4.3     1
# Name: sepal_length, dtype: int64

# %%
sns.distplot(iris['sepal_width'])
# Out:
# C:\Users\ratnachaitanyaraju.b\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal_width', ylabel='Density'>

# %%
sns.distplot(iris['petal_length'],kde=True,bins=20,color='red')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Density'>

# %%
sns.barplot(x='petal_length',y='sepal_width',data=iris)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>

# %%
sns.boxplot('petal_width','sepal_width',data=iris)
# Out:
# C:\Users\ratnachaitanyaraju.b\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>

# %%
sns.boxplot('petal_width','sepal_width',data=iris,palette='rainbow')
# Out:
# C:\Users\ratnachaitanyaraju.b\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>

# %%
sns.boxplot(data=iris,orient='v')
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x='sepal_width',y='sepal_length',data=iris,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>
